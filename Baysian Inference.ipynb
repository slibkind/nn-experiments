# %%
import numpy as np
import numpy.matlib

import math
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, Range1d, LabelSet, Label, HoverTool
from bokeh.plotting import *

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5d3e6de0-1b5d-4972-ad8d-2357d446437b">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Bayesian Inference Example from Macckay's Lecture 10
# https://www.youtube.com/watch?v=mDVE0M-xQlc
#
#
# We have $N$ data points $x_n$ with $n\in (1,...,N)$. Using Bayes rule we have:
#
# $$P(\lambda|x_n,\mathcal{H}) = \frac{P(x_n|\lambda,\mathcal{H})P(\lambda|\mathcal{H})}{P(x_n,\mathcal{H})}$$
#
# In this case $$P(x|\lambda) = \frac{e^{x/\lambda}}{Z}$$ where $$Z = \int_{a}^{b}e^{-x/\lambda}dx=\lambda(e^{-a/\lambda}-e^{-b/\lambda})$$

# %%
data = np.array([3,5, 9])

a = 1
b = 20

Z = lambda L,a,b: L*(np.exp(-a/L)-np.exp(-b/L))

likelihood = lambda L,x,Z: np.exp(-x/L)/Z 

lambdas = np.logspace(-2.1,4,num=100,base=10)
likes = []
for i in range(len(data)):
    x = data[i]
    likes.append([])
    for L in lambdas:
        likes[i].append(likelihood(L,x,Z(L,a,b)))

# %%
p = figure(title='not normalized posterior', x_range=Range1d(-1, np.log10(100)),plot_width=400, plot_height=300)

p.multi_line([np.log10(lambdas) for _ in likes], likes)
p.xaxis[0].axis_label = '$\lambda$'
p.yaxis[0].axis_label = 'probabilty'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a3de60a9-bc92-450b-9d91-87ff6a6d54bf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a3de60a9-bc92-450b-9d91-87ff6a6d54bf");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a3de60a9-bc92-450b-9d91-87ff6a6d54bf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a3de60a9-bc92-450b-9d91-87ff6a6d54bf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"444753fe-e71f-4c81-a4ad-202d9b7750ae":{"roots":{"references":[{"attributes":{"plot":{"id":"15aebd7c-4cb3-4c04-b2bf-6801556447e3","subtype":"Figure","type":"Plot"}},"id":"838266cd-412a-42d8-8f7c-13aa7be30b3b","type":"ResetTool"},{"attributes":{"plot":{"id":"15aebd7c-4cb3-4c04-b2bf-6801556447e3","subtype":"Figure","type":"Plot"}},"id":"dcea8287-fa8e-4472-907d-15e9f447586d","type":"SaveTool"},{"attributes":{"data_source":{"id":"694455f7-c3cb-492e-a6d0-5a4bfc021afc","type":"ColumnDataSource"},"glyph":{"id":"e9563c66-783e-45ce-817f-1c77be4bef21","type":"MultiLine"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"152f4778-2887-4fb8-88a1-b444031b9889","type":"MultiLine"},"selection_glyph":null},"id":"d509f055-e5f2-4ed5-8a10-2d2fb596630c","type":"GlyphRenderer"},{"attributes":{},"id":"09598498-69d2-4c74-9f49-296e30536911","type":"BasicTickFormatter"},{"attributes":{},"id":"bed9062a-807e-44c2-ad4a-0705d21c777f","type":"ToolEvents"},{"attributes":{"plot":{"id":"15aebd7c-4cb3-4c04-b2bf-6801556447e3","subtype":"Figure","type":"Plot"}},"id":"1a83cc6c-a6c2-4a26-9341-c3289ff1365f","type":"PanTool"},{"attributes":{},"id":"084e6033-322a-4ddb-9fe5-546778cc3e5c","type":"BasicTicker"},{"attributes":{"plot":{"id":"15aebd7c-4cb3-4c04-b2bf-6801556447e3","subtype":"Figure","type":"Plot"},"ticker":{"id":"de7733ed-d407-401a-a5da-09ded38c9223","type":"BasicTicker"}},"id":"ab966343-8e16-4a20-9f3d-30de2a6fd374","type":"Grid"},{"attributes":{"axis_label":"probabilty","formatter":{"id":"e10e6b03-6e30-4c92-8997-c8bc99084989","type":"BasicTickFormatter"},"plot":{"id":"15aebd7c-4cb3-4c04-b2bf-6801556447e3","subtype":"Figure","type":"Plot"},"ticker":{"id":"084e6033-322a-4ddb-9fe5-546778cc3e5c","type":"BasicTicker"}},"id":"fc7f084e-9c07-45ae-8112-af9604adc68c","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":
6","subtype":"Figure","type":"Plot"},"ticker":{"id":"ecdc793f-6225-45b8-8842-fdae604cd53b","type":"BasicTicker"}},"id":"b2d5497b-efd3-40cf-9a04-2fe4644d396b","type":"LinearAxis"},{"attributes":{"plot":{"id":"0e71d2ad-2d11-435d-94a5-6c2decd010c6","subtype":"Figure","type":"Plot"}},"id":"c7856666-91b7-4bf4-b980-4a539f7dc588","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"b2d5497b-efd3-40cf-9a04-2fe4644d396b","type":"LinearAxis"}],"left":[{"id":"dc74a39a-6a5e-426c-8bfa-721e47fb01e3","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"b2d5497b-efd3-40cf-9a04-2fe4644d396b","type":"LinearAxis"},{"id":"7cf90fe8-cad3-4a09-a608-be174254bfbc","type":"Grid"},{"id":"dc74a39a-6a5e-426c-8bfa-721e47fb01e3","type":"LinearAxis"},{"id":"8dd77fa3-4903-4617-8a40-2b57316c05de","type":"Grid"},{"id":"4bf36993-9563-447a-b65c-bce16fcdc78a","type":"BoxAnnotation"},{"id":"17a815a6-4682-407f-b50b-493315a84b91","type":"GlyphRenderer"}],"title":{"id":"99a520c3-392f-4974-99b4-fde68fff102e","type":"Title"},"tool_events":{"id":"930733fc-eee3-4d65-869d-9f19b8dd8a3c","type":"ToolEvents"},"toolbar":{"id":"e7af9cec-853b-4bcc-904f-aae279409974","type":"Toolbar"},"x_range":{"id":"9451829c-36af-4477-9166-1e12f3e82ac8","type":"Range1d"},"y_range":{"id":"2d1f6403-018e-4870-bfd2-549570cdef66","type":"DataRange1d"}},"id":"0e71d2ad-2d11-435d-94a5-6c2decd010c6","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"9b7b83b6-fdd9-46ee-a7b5-ac61d6d268dd","type":"ColumnDataSource"},"glyph":{"id":"0d51bd03-3779-4780-80e4-c231bb2ea6b4","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c6a629b6-a336-4d61-a2d8-5f542a5c9203","type":"Line"},"selection_glyph":null},"id":"17a815a6-4682-407f-b50b-493315a84b91","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c6a629b6-a336-4d61-a2d8-5f542a5c9203","type":"Line"},{"attributes":{},"id":"f600bf3b-e4ed-4739-b0ed-4735116b5338","type":"BasicTicker"},{"attributes":{"overlay":{"id":"4bf36993-9563-447a-b65c-bce16fcdc78a","type":"BoxAnnotation"},"plot":{"id":"0e71d2ad-2d11-435d-94a5-6c2decd010c6","subtype":"Figure","type":"Plot"}},"id":"50364835-6526-4522-acdb-622afe59f09e","type":"BoxZoomTool"},{"attributes":{},"id":"7e38436d-ec65-4e94-9f00-788e31fcf2ab","type":"BasicTickFormatter"},{"attributes":{},"id":"930733fc-eee3-4d65-869d-9f19b8dd8a3c","type":"ToolEvents"},{"attributes":{"axis_label":"likelihood/","formatter":{"id":"073b3d23-6983-4c7a-be12-62921edef756","type":"BasicTickFormatter"},"plot":{"id":"0e71d2ad-2d11-435d-94a5-6c2decd010c6","subtype":"Figure","type":"Plot"},"ticker":{"id":"f600bf3b-e4ed-4739-b0ed-4735116b5338","type":"BasicTicker"}},"id":"dc74a39a-6a5e-426c-8bfa-721e47fb01e3","type":"LinearAxis"},{"attributes":{"plot":{"id":"0e71 ...

# %% [markdown]
# Now suppose we have data which seems to be coming from a mixture of two exponentials.
#
# We have $N$ data points $x_n$ with $n\in (1,...,N)$. Using Bayes rule we have:
#
# $$P(\lambda_1, |x_n,\mathcal{H}) = \frac{P(x_n|\lambda,\mathcal{H})P(\lambda|\mathcal{H})}{P(x_n,\mathcal{H})}$$
#
# In this case $$P(x|\lambda) = \frac{e^{x/\lambda}}{Z}$$ where $$Z = \int_{a}^{b}e^{-x/\lambda}dx=\lambda(e^{-a/\lambda}-e^{-b/\lambda})$$
